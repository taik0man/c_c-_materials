# %%
#@title 前処理コード { display-mode: "form"}
#@markdown ※このセルの実行をお願いします※

import os

def submit_result(name, code_output, question_no):
    import requests
    text_no = "c_ALL"

    # Google FormsのURL
    FORM_URL = "https://docs.google.com/forms/d/e/1FAIpQLSdIHcdAT0dqO9qoDWgwkmKHRIvz8aedslvk81f8em0aayInjQ/formResponse"

    # Formsの入力項目ID
    data = {
        'entry.1049158114': name,  # 学生ID用のエントリーID
        'entry.1116133824': code_output,  # 実行結果用のエントリーID
        'entry.1164627803': text_no, # テキスト番号のエントリーID
        'entry.1429487951': question_no # 問題番号のエントリーID
    }

    try:
        requests.post(FORM_URL, data=data)
        print("結果を提出しました")
    except Exception as e:
        print(f"提出時にエラーが発生しました: {e}")


# def code_run():
#     # コンパイルと実行の結果を全て1つのファイルに記録
#     !{ gcc *.c -o program 2>&1 && echo "---プログラム実行結果---" && ./program 2>&1; } > result.txt
#     !cat result.txt

def compile_program():
    """
    Cプログラムをコンパイルし、結果を result_compile.txt に保存。
    コンパイルエラーがあれば表示。
    """
    compile_command = (
        "gcc -fsanitize=address -fsanitize=undefined -g -O1 -Wall -Wextra -pedantic "
        "-Wconversion -Werror *.c -o program 2> result_compile.txt"
    )
    os.system(compile_command)

    # コンパイル結果を表示
    with open("result_compile.txt", "r") as f:
        compile_output = f.read()

    if compile_output.strip():  # コンパイルエラーがあれば内容を表示
        print("=== コンパイル時のエラー ===")
        print(compile_output)
        return False
    else:
        print("=== コンパイル成功 ===")
        return True

def run_program():
    """
    実行可能ファイルを実行し、結果を result_run.txt に保存。
    実行時のエラーがあれば表示。
    """
    if not os.path.exists("program"):
        print("エラー: 実行ファイルが存在しません。コンパイルが失敗しています。")
        return

    run_command = "./program > result_run.txt 2>&1"
    os.system(run_command)

    # 実行結果を表示
    with open("result_run.txt", "r") as f:
        run_output = f.read()

    print("=== プログラムの実行結果 ===")
    print(run_output)



def submit(question_no):
  if name == "" or name == "あなたの名前":
    print("nameに名前を入力し、再度提出してください。")
  else:
    try:
        with open('result_run.txt', 'r') as f:
            result = f.read()
        submit_result(name, result, question_no)
    except FileNotFoundError:
        print("result_run.txtが見つかりません。まずプログラムを実行してください。")

print("実行されました")

# %% [markdown]
# Github上のURLをエンコードするコード：

# %%
import base64

# 元のURL
url = "https://XXXXXX"

# GitHubのURLをraw.githubusercontent.comのURLに変換
# blobをrawに変更し、githubをraw.githubusercontent.comに変更
raw_url = url.replace("github.com", "raw.githubusercontent.com").replace("/blob/", "/")

# Base64エンコード
encoded_url = base64.b64encode(raw_url.encode()).decode()

print("エンコードされたURL:")
print(encoded_url)

# %% [markdown]
# # C_1 課題1
# 1. `%%writefile main.c` はGoogle Colab上でCのソースファイルを作成するための特別なコマンドです。
#
# 2. プログラムの構造：<br>
# ※ 詳細は別のテキストで解説していきます。<br>
#    - `char favorite_food[256]` で256文字まで保存できる文字列配列を用意しています
#    - `strcpy()` 関数で好きな食べ物の名前を設定できます
#    - `printf()` で結果を出力します
#
# 実行の際は、"りんご"の部分を自分の好きな食べ物に書き換えてください。例えば「カレー」や「ラーメン」などに変更できます。
#
# このプログラムは、課題提出方法を学ぶためのものです。ぜひ色々な食べ物名を試してみてください。
#
# これからのテキストもがんばってくださいね！

# %% [markdown]
# # C_2 課題1
#
# この課題は、**セミコロン（;）** や **カッコの使い方** を確認する問題です。
#
# **期待する実行結果：**
# > Hello, World!
#
#
# 次のセルのプログラムには2つの文法エラーがあります。
#
# 期待する実行結果になるよう、プログラムを修正してください。
#
# ## 進め方
#
# ### ステップ1：まずそのまま実行してみよう
# 下の「%%writefile main.c」から始まる、プログラムが書かれているセルと、「コンパイル＆実行」セルをそのまま実行してください。
# コンパイルエラーが表示されます。
#
# <br>
#
# ### ステップ2：エラーメッセージを読もう
# 例えば `main.c:4:27: error: expected ')' before ';' token` というエラーは、
# 「main.cの4行目27文字目で、`;`の前に`)`があるはずだが見つからない」という意味です。<br>
# このように、**エラーメッセージには「何行目で」「何が問題か」が書かれています。**
# これをヒントにエラー箇所を探しましょう。
#
# ⚠️ **注意：** エラーの行番号はファイル（main.c）の行番号です。セル上では先頭に `%%writefile main.c` の行があるため、**セル上の行番号はエラー表示より1行多く**なります（例：エラーの4行目 → セル上では5行目）。
#
# <br>
#
# ### ステップ3：コードを修正して再実行しよう
# エラー箇所を修正したら、もう一度「コード」セルと「コンパイル＆実行」セルを実行してください。
# 「コンパイル成功」と表示され、期待通りの結果が出ればOKです。
#
# <br>
#
# ### ステップ4：提出
# 正しい結果が出たら「課題提出」セルを実行し、課題を提出してください。

# %%
# %%writefile main.c
# #include <stdio.h>
# int main() {
#     // これはコメント行です
#     printf("Hello, World!";
#     return 0
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# # C_2 課題1 模範解答
#
# エラーの理由：
# 1. `printf("Hello, World!"` の閉じ括弧 `)` が欠けています。C言語では関数呼び出しの括弧は必ずペアで必要です。
# 2. `return 0` の末尾にセミコロン `;` が欠けています。C言語では文の終わりには必ずセミコロンが必要です。

# %%
# %%writefile main.c
# #include <stdio.h>
# int main() {
#     // これはコメント行です
#     printf("Hello, World!");  // ★修正：閉じ括弧 ) を追加
#     return 0;  // ★修正：セミコロンを追加
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# # C_3 課題1
#
# この課題では、**printf の書式指定子（%f など、表示形式を指定する記号）** の使い方を確認します。
#
# 次のセルのプログラムは、円の半径から面積を計算し、小数点第二位まで表示するプログラムです。<br>
#
# **期待する実行結果：**
# ```
# 面積は 78.50 です
# ```
# 次のセルのプログラムにはエラーがあります。期待する実行結果になるよう、プログラムを修正してください。
#
# <br>
#
#
# ## ステップ1：まずそのまま実行してみよう
#
# 下の「%%writefile main.c」から始まる、プログラムが書かれているセルと「コンパイル＆実行」セルをそのまま実行してください。
# コンパイルは成功しますが、**実行結果が期待と違う**はずです。どこが違うか見比べてみましょう。
#
# <br>
#
# ## ステップ2：出力結果を見比べよう
#
# 出力結果と期待する実行結果を見比べて、異なる場合、なぜ、どこが原因か、を考えてみましょう。
#
# 💡 **ヒント：** 講座の「printf関数」セクションにある **「よく使うオプション」** の表を見返してみましょう。
#
# <br>
#
# ## ステップ3：コードを修正して再実行しよう
#
# 修正したら、「コード」セルと「コンパイル＆実行」セルを**もう一度実行**してください。
# `コンパイル成功` と表示され、出力が `面積は 78.50 です` になればOKです！
#
# <br>
#
# ## ステップ4：提出
#
# 正しい結果が確認できたら、「課題提出」セルを実行して提出してください。

# %%
# %%writefile main.c
# #include <stdio.h>
#
# int main() {
#     // 半径を格納する変数（Input）
#     float radius = 5.0f;
#
#     // 面積を計算（Process）
#     float area = 3.14f * radius * radius;
#
#     // 結果を表示（Output）
#     printf("面積は %f です", area);
#
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# # C_3 課題1 模範解答
#
#
# エラーの理由：
# 1. printfのフォーマット指定子が`%f`となっており、小数点以下の表示桁数が指定されていません。そのため、小数点以下が6桁まで表示されてしまいます。
# 2. 期待する実行結果では小数点第二位まで表示する必要があるため、フォーマット指定子を`%.2f`に修正する必要があります。

# %%
# %%writefile main.c
# #include <stdio.h>
#
# int main() {
#     // 半径を格納する変数（Input）
#     float radius = 5.0f;
#
#     // 面積を計算（Process）
#     float area = 3.14f * radius * radius;
#
#     // 結果を表示（Output）
#     printf("面積は %.2f です", area);  // ★修正：%fを%.2fに変更し小数点以下2桁に指定
#
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# # C_4 課題1
#
# この課題では、**変数の型（データの種類を表す指定）** と代入する値が正しく対応しているかを確認します。
#
#
#
# **期待する実行結果：**
# ```
# カウント：5
# ```
# 次のセルのプログラムにはエラーがあります。期待する実行結果になるよう、プログラムを修正してください。
#
# <br>
#
# ## ステップ1：まずそのまま実行してみよう
#
# 下の「%%writefile main.c」から始まる、プログラムが書かれているセルと「コンパイル＆実行」セルをそのまま実行してください。
# **コンパイルエラーが表示されます。**
#
# <br>
#
# ## ステップ2：エラーメッセージを読もう
#
# 表示されたエラーメッセージを読んでみましょう。
#
# エラーメッセージには **何行目で・何が問題か** が書かれています。メッセージを手がかりに、コードのどこをどう直せばよいか考えてみましょう。
#
#
# <br>
#
# ## ステップ3：コードを修正して再実行しよう
#
# 修正したら、「コード」セルと「コンパイル＆実行」セルを**もう一度実行**してください。
# `コンパイル成功` と表示され、出力が `カウント：5` になればOKです！
#
# <br>
#
# ## ステップ4：提出
#
# 正しい結果が確認できたら、「課題提出」セルを実行して提出してください。
#
#
# ⚠️ **注意：** エラーの行番号はファイル（main.c）の行番号です。セル上では先頭に `%%writefile main.c` の行があるため、**セル上の行番号はエラー表示より1行多く**なります

# %%
# %%writefile main.c
# # include <stdio.h>
#
# int main() {
#     int count = "5";
#     printf("カウント：%d\n", count);
#     return 0;
# }

# %% [markdown]
# # C_4 課題1 模範解答
# エラーの理由：
# 1. int型の変数`count`に文字列リテラル`"5"`を代入しようとしています。文字列リテラルはchar型の配列として扱われるため、int型の変数に直接代入することはできません。
# 2. 数値の5を表現する場合は、クォーテーションマーク`""`を付けずに整数リテラル`5`として記述する必要があります。

# %%
# %%writefile main.c
# # include <stdio.h>
#
# int main() {
#     int count = 5;  // ★修正：文字列"5"を整数リテラル5に変更
#     printf("カウント：%d\n", count);
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# # C_4 課題1 別解
#
# エラーの原因に対する別のアプローチとして：
# 1. 文字`'5'`として扱う場合は、変数の型をchar型として宣言し、シングルクォーテーション`''`で囲んで代入します。
# 2. 出力時のフォーマット指定子も、文字を表示する`%c`を使用します。

# %%
# %%writefile main.c
# # include <stdio.h>
#
# int main() {
#     char count = '5';  // ★修正：char型に変更し文字リテラル'5'を代入
#     printf("カウント：%c\n", count);  // ★修正：書式指定子を%dから%cに変更
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# ---
# # C_5 課題1
#
# この課題では、**関数の引数（関数に渡す入力データ）の正しい書き方**を確認します。
#
# **期待する実行結果：**
# ```
# === プログラムの実行結果 ===
# 三角形の面積1: 13.500000
# ```
#
# 次のセルのプログラムにはエラーがあります。期待する実行結果になるよう、プログラムを修正してください。
#
# <br>
#
# ## ステップ1：まずそのまま実行してみよう
#
# 下の「%%writefile main.c」から始まる、プログラムが書かれているセルと「コンパイル＆実行」セルを、**何も修正せずに**そのまま実行してください。
# **コンパイルエラーが表示されます。**
#
# <br>
#
# ## ステップ2：エラーメッセージを読もう
#
# 表示されたエラーメッセージを確認しましょう。
# エラーメッセージには **何行目で何が問題か** が書かれています。該当する行を見て、関数定義の引数の書き方がルール通りか確認しましょう。
#
#
# 💡 **ヒント：** 講座の「1.2. 引数（入力）について」セクションにある引数のルールを見返してみましょう。
#
# <br>
#
# ## ステップ3：コードを修正して再実行しよう
#
# 修正したら、「コード」セルと「コンパイル＆実行」セルを**もう一度実行**してください。
# `コンパイル成功` と表示され、出力が `三角形の面積1: 13.500000` になればOKです！
#
# <br>
#
# ## ステップ4：提出
#
# 正しい結果が確認できたら、「課題提出」セルを実行して提出してください。
#
#
# ⚠️ **注意：** エラーの行番号はファイル（main.c）の行番号です。セル上では先頭に `%%writefile main.c` の行があるため、**セル上の行番号はエラー表示より1行多く**なります

# %%
# %%writefile main.c
# #include <stdio.h>
#
# float calc_triangle(float base, height) {
#     float area = (base * height) / 2.0f;
#     return area;
# }
#
# int main() {
#     float b = 6.0;
#     float h = 4.5;
#
#     float result1 = calc_triangle();
#     printf("三角形の面積1: %f\n", result1);
#
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# # C_5 課題1 模範解答
#
# エラーの理由：
# 1. `calc_triangle`関数の引数宣言において、`height`パラメータの型（float）が指定されていません。C言語では各パラメータに対して型を明示的に指定する必要があります。
# 2. `calc_triangle`関数を呼び出す際に引数が指定されていません。関数に定義されているパラメータ`base`と`height`に対応する値（`b`と`h`）を渡す必要があります。

# %%
# %%writefile main.c
# #include <stdio.h>
#
# float calc_triangle(float base, float height) {  // ★修正：heightにfloat型を指定
#     float area = (base * height) / 2.0f;
#     return area;
# }
#
# int main() {
#     float b = 6.0;
#     float h = 4.5;
#
#     float result1 = calc_triangle(b, h);  // ★修正：引数b, hを渡す
#     printf("三角形の面積1: %f\n", result1);
#
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# ---
# # C_5 課題2
#
#
# この課題では、**スコープ（変数が使える範囲）** と **戻り値（関数が返す結果）の受け渡し** を確認します。
#
# **期待する実行結果：**
# ```
# === プログラムの実行結果 ===
# 年齢は: 20歳
# ```
#
# 次のセルのプログラムにはエラーがあります。期待する実行結果になるよう、プログラムを修正してください。
#
# <br>
#
# ## ステップ1：まずそのまま実行してみよう
#
# 下の「%%writefile main.c」から始まる、プログラムが書かれているセルと「コンパイル＆実行」セルをそのまま実行してください。
# **コンパイルエラーが表示されます。**
#
# <br>
#
# ## ステップ2：エラーメッセージを読もう
#
# 表示されたエラーメッセージを確認しましょう。エラーメッセージには **何行目で何が問題か** が書かれています。
#
# ⚠️ **注意：** エラーの行番号はファイル（main.c）の行番号です。セル上では先頭に `%%writefile main.c` の行があるため、**セル上の行番号はエラー表示より1行多く**なります
#
#
# <br>
#
# ## ステップ3：コードを修正して再実行しよう
#
# 修正したら、「コード」セルと「コンパイル＆実行」セルを**もう一度実行**してください。
# `コンパイル成功` と表示され、出力が `年齢は: 20歳` になればOKです！
#
# <br>
#
# ## ステップ4：提出
#
# 正しい結果が確認できたら、「課題提出」セルを実行して提出してください。

# %%
# %%writefile main.c
# #include <stdio.h>
#
# int set_age() {
#     int age = 20;
#     return age;
# }
#
# void show_age() {
#     printf("年齢は: %d歳\n", age);
# }
#
# int main() {
#     set_age();
#     show_age();
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# # C_5 課題2 模範解答
#
# エラーの理由：
# 1. `set_age`関数で宣言した`age`変数は、その関数内でのみ有効です。returnした値を変数に代入して使う必要があります。
# 2. `show_age`関数では`age`変数にアクセスできません。引数ageを追加する必要があります。

# %%
# %%writefile main.c
# #include <stdio.h>
#
# int set_age() {
#     int age = 20;
#     return age;
# }
#
# void show_age(int age) {  // ★修正：引数int ageを追加して年齢を受け取る
#     printf("年齢は: %d歳\n", age);
# }
#
# int main() {
#     int age = set_age();  // ★修正：戻り値を変数ageで受け取る
#     show_age(age);  // ★修正：引数ageを渡す
#     return 0;
# }

# %% [markdown]
# ---
# # C_6 課題1
#
# この課題では、**標準関数** を自分で調べて使う力を確認します。
#
# **期待する実行結果：**
# ```
# 文字列"100"から変換した数値: 100
# ```
#
# 次のセルのプログラムにはエラーがあります。期待する実行結果になるよう、プログラムを修正してください。
#
# <br>
#
# ## ステップ1：まずそのまま実行してみよう
#
# 下の「%%writefile main.c」から始まる、プログラムが書かれているセルと「コンパイル＆実行」セルをそのまま実行してください。
# **コンパイルエラー**が表示されます。
#
# <br>
#
# ## ステップ2：エラーメッセージを読もう
#
# 表示されたエラーメッセージを確認しましょう。エラーメッセージには **何行目で何が問題か** が英語で書かれています。
# 「empty filename in #include」は「#include のファイル名が空です」という意味です。
#
# 💡 ヒント：このプログラムでは「文字列を数値に変換する関数」が必要です。講座の **セクション1** にあるヘッダーファイルの一覧表と、**セクション2（標準関数の調べ方）** を見返して、どのヘッダーファイルとどの関数を使えばよいか調べてみましょう。
#
# <br>
#
# ## ステップ3：コードを修正して再実行しよう
#
# 修正したら、「コード」セルと「コンパイル＆実行」セルを**もう一度実行**してください。
# `コンパイル成功` と表示され、出力が `文字列"100"から変換した数値: 100` になればOKです！
#
# <br>
#
# ## ステップ4：提出
#
# 正しい結果が確認できたら、「課題提出」セルを実行して提出してください。
#
# <br>
#
# ⚠️ **注意：** エラーの行番号はファイル（main.c）の行番号です。セル上では先頭に `%%writefile main.c` の行があるため、**セル上の行番号はエラー表示より1行多く**なります

# %%
# %%writefile main.c
# #include <stdio.h>
# #include <> // ヘッダーも追加
#
# int main() {
#     char str[] = "100";
#     int value = /*ここに記述*/;
#     printf("文字列\"%s\"から変換した数値: %d\n", str, value);
#
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# # C_6 課題1 模範解答
#
#
# ## atoi関数
# ```c
# int value = atoi(str);
# ```
# - `<stdlib.h>`で定義されています
# - ASCII文字列をinteger（整数）に変換します
# - 引数：変換する文字列
# - 戻り値：変換された整数値
# - エラー時は0を返します
# - 使用例：文字列形式の数値を計算に使用する場合など

# %%
# %%writefile main.c
# #include <stdio.h>
# #include <stdlib.h>  // ★修正：stdlib.hヘッダーを指定
#
# int main() {
#     char str[] = "100";
#     int value = atoi(str);  // ★修正：atoi関数で文字列を整数に変換
#     printf("文字列\"%s\"から変換した数値: %d\n", str, value);
#
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# # C_7 課題1
#
# この課題では、**配列のインデックス（データの番号）が0から始まる** ことを確認します。
#
# **期待する実行結果：**
# ```
# 4月の売上: 180
# ```
#
# 次のセルのプログラムにはエラーがあります。期待する実行結果になるよう、プログラムを修正してください。
#
# <br>
#
# ## ステップ1：まずそのまま実行してみよう
#
# 下の `%%writefile main.c` から始まる、プログラムが書かれているセルと「コンパイル＆実行」セルをそのまま実行してください。
# コンパイルは成功しますが、**実行結果が期待と違う**はずです。どこが違うか見比べてみましょう。
#
# <br>
#
# ## ステップ2：出力結果を見比べよう
#
# 出力された数値と、期待する実行結果の数値を見比べてください。
# 表示された売上は何月のものでしょうか？ なぜ4月ではない値が出たのか、考えてみましょう。
#
# 💡 ヒント：講座の「1.2. 配列の基本 - データの取り出し方」のインデックスの例を見返してみましょう。
#
# <br>
#
# ## ステップ3：コードを修正して再実行しよう
#
# 修正したら、「コード」セルと「コンパイル＆実行」セルを**もう一度実行**してください。
# `コンパイル成功` と表示され、出力が `4月の売上: 180` になればOKです！
#
# <br>
#
# ## ステップ4：提出
#
# 正しい結果が確認できたら、「課題提出」セルを実行して提出してください。
#
# <br>
#
# ⚠️ **注意：** エラーの行番号はファイル（main.c）の行番号です。セル上では先頭に `%%writefile main.c` の行があるため、**セル上の行番号はエラー表示より1行多く**なります。

# %%
# %%writefile main.c
# # include <stdio.h>
#
# int main(){
#     // 1月から12月の売上データ
#     int sales[] = {100, 150, 120, 180, 130, 200, 170, 160, 190, 210, 250, 300};
#     printf("4月の売上: %d\n", sales[4]);
#     return 0;
#
# }

# %% [markdown]
# # C_7 課題1 模範解答
#
# エラーの理由：
# 1. sales[4]は5番目の要素（5月の売上）を指します。配列のインデックスは0から始まるためです。
#
# 4月のデータにアクセスするために、`sales[4]`を`sales[3]`に変更する必要があります。

# %%
# %%writefile main.c
# #include <stdio.h>
#
# int main() {
#     // 1月から12月の売上データ
#     int sales[] = {100, 150, 120, 180, 130, 200, 170, 160, 190, 210, 250, 300};
#
#     // 4月の売上を表示（インデックスは3を使用）
#     printf("4月の売上: %d\n", sales[3]);  // ★修正：インデックスを4から3に変更（0始まり）
#
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# # C_7 課題2
#
# この課題では、**C言語での文字列の結合方法**を確認します。
#
# 次のセルのプログラムにはエラーがあります。期待する実行結果になるよう、プログラムを修正してください。
#
# **期待する実行結果：**
# ```
# text1: Hello World!
# ```
#
# <br>
#
# ## ステップ1：まずそのまま実行してみよう
#
# 下の `%%writefile main.c` から始まる、プログラムが書かれているセルと「コンパイル＆実行」セルを、そのまま実行してください。
# **コンパイルエラーが表示されます。**
#
# <br>
#
# ## ステップ2：エラーメッセージを読もう
#
# 表示されたエラーメッセージを読んでみましょう。エラーメッセージには**何行目で何が問題か**が書かれています。
#
# - `invalid operands to binary xxx` → 「この演算子（`+` や `=`）はこの型には使えません」という意味です
#
# 💡 ヒント：講座の「2.5. よくある間違い - 2. 文字列の代入ミス」と、課題文の上にあるヒントを見返してみましょう。また、結合後の文字列が収まるだけの配列サイズがあるかも確認しましょう。
#
# ※ C言語では文字列の結合にstrcat関数を使用する必要があります。
#
# <br>
#
# ## ステップ3：コードを修正して再実行しよう
#
# 修正したら、「コード」セルと「コンパイル＆実行」セルを**もう一度実行**してください。
# `コンパイル成功` と表示され、出力が `text1: Hello World!` になればOKです！
#
# <br>
#
# ## ステップ4：提出
#
# 正しい結果が確認できたら、「課題提出」セルを実行して提出してください。
#
# <br>
#
# ⚠️ **注意：** エラーの行番号はファイル（main.c）の行番号です。セル上では先頭に `%%writefile main.c` の行があるため、**セル上の行番号はエラー表示より1行多く**なります。

# %%
# %%writefile main.c
# #include <stdio.h>
# #include <string.h>
#
# int main() {
#
#     char text1[] = "Hello ";
#     char text2[] = "World!";
#
#     text1 = text1 + text2;
#
#     printf("text1: %s\n", text1); // 確認用
#
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# # C_7 課題2 模範解答
#
# エラーの理由：
# 1. C言語では文字列の結合に `+` 演算子は使えません。代わりに `strcat()` 関数を使用する必要があります。
# 2. 配列 `text1` のサイズが小さすぎます。結合後の文字列全体（"Hello World!"）と終端文字（\0）を格納できるように、最低13バイトのサイズが必要です。
# 3. C言語では配列は代入演算子 `=` で直接結合できません。配列名は配列の先頭アドレスを示す定数であり、代入はできません。

# %%
# %%writefile main.c
# #include <stdio.h>
# #include <string.h>
#
# int main() {
#
#     char text1[13] = "Hello ";  // ★修正：配列サイズを13に拡大（結合後の文字数12+終端\0）
#     char text2[] = "World!";
#
#     strcat(text1, text2);  // ★修正：+演算子をstrcat関数に変更
#
#     printf("text1: %s\n", text1); // 確認用
#
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# ---
# # C_9 課題1
# この課題では、**while文の繰り返し条件（ループをいつまで続けるかの指定）** が正しく設定されているかを確認します。
#
# ある店舗の在庫管理プログラムを作成しています。<br>
# 在庫が5個以下になったら「在庫が少なくなりました」と表示し、補充注文をする必要があります。<br>
#
#
# **期待する実行結果：**
# ```
# 現在の在庫: 8
# 現在の在庫: 7
# 現在の在庫: 6
# 現在の在庫: 5
# 在庫が少なくなりました
# 現在の在庫: 4
# 在庫が少なくなりました
# 現在の在庫: 3
# 在庫が少なくなりました
# 現在の在庫: 2
# 在庫が少なくなりました
# 現在の在庫: 1
# 在庫が少なくなりました
# 最終在庫: 0
# ```
#
# 次のセルのプログラムにはエラーがあります。期待する実行結果になるよう、プログラムを修正してください。
#
# <br>
#
# ## ステップ1：まずそのまま実行してみよう
#
# 下の「%%writefile main.c」から始まる、プログラムが書かれているセルと「コンパイル＆実行」セルを、**何も修正せずに**そのまま実行してください。
# コンパイルは成功しますが、**実行結果が期待と違う**はずです。どこが違うか見比べてみましょう。
#
# <br>
#
# ## ステップ2：出力結果を見比べよう
#
# 出力結果と期待する実行結果を見比べてください。表示される行数や内容に違いはありませんか？
# なぜその違いが生まれるのか、while文の条件に注目して考えてみましょう。
#
# 💡 **ヒント：** 講座の「1.2. 繰り返しのもう1つの形（while文）」にあるwhile文の条件の書き方を見返してみましょう。
#
# <br>
#
# ## ステップ3：コードを修正して再実行しよう
#
# 修正したら、「コード」セルと「コンパイル＆実行」セルを**もう一度実行**してください。
# `コンパイル成功` と表示され、出力が期待する実行結果と一致すればOKです！
#
# <br>
#
# ## ステップ4：提出
#
# 正しい結果が確認できたら、「課題提出」セルを実行して提出してください。
#
# ⚠️ **注意：** エラーの行番号はファイル（main.c）の行番号です。セル上では先頭に `%%writefile main.c` の行があるため、**セル上の行番号はエラー表示より1行多く**なります。

# %%
# %%writefile main.c
# #include <stdio.h>
#
# int main() {
#     int stock = 8;
#     while (stock >= 5) {
#         printf("現在の在庫: %d\n", stock);
#         stock--;
#         if (stock <= 5) {
#             printf("在庫が少なくなりました\n");
#         }
#     }
#     printf("最終在庫: %d\n", stock);
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# # C_9 課題1 模範解答
#
# エラーの理由：
# 1. ループの継続条件が `stock >= 5` となっているため、在庫が4以下になった時点でループが終了してしまいます。在庫が1-4個の場合も処理する必要があります。
# 2. `stock--` の位置が `if文` の前にあるため、在庫6の時に警告メッセージが出力されてしまいます。在庫チェックを先に行う必要があります。

# %%
# %%writefile main.c
# #include <stdio.h>
#
# int main() {
#     int stock = 8;
#     while (stock > 0) {  // ★修正：条件をstock > 0に変更（在庫がある限り続ける）
#         printf("現在の在庫: %d\n", stock);
#         if (stock <= 5) {
#             printf("在庫が少なくなりました\n");
#         }
#         stock--;  // ★修正：stock--をif判定の後に移動
#     }
#     printf("最終在庫: %d\n", stock);
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# # C_9 課題2
#
#
# この課題では、**for文で配列（データの並び）にアクセスするときの開始位置と終了条件** が正しいかを確認します。
#
# 1週間分の売上データを処理するプログラムです。<br>各日の売上を表示し、最後に合計を表示します。<br>
#
# **期待する実行結果：**
# ```
# === 売上集計開始 ===
# 1日目の売上: 1000円
# 2日目の売上: 1500円
# 3日目の売上: 2000円
# 4日目の売上: 1800円
# 5日目の売上: 1600円
# 6日目の売上: 2200円
# 7日目の売上: 1900円
# 週間合計: 12000円
# ```
#
#
# 次のセルのプログラムにはエラーがあります。期待する実行結果になるよう、プログラムを修正してください。
#
# <br>
#
# ## ステップ1：まずそのまま実行してみよう
#
# 下の「%%writefile main.c」から始まる、プログラムが書かれているセルと「コンパイル＆実行」セルをそのまま実行してください。
# コンパイルは成功しますが、**実行結果が期待と違う**はずです。どこが違うか見比べてみましょう。
#
# <br>
#
# ## ステップ2：出力結果を見比べよう
#
# 出力結果と期待する実行結果を見比べてください。各日の売上金額や合計金額に違いはありませんか？
# なぜその違いが生まれるのか、for文の中で配列のどの位置のデータを取り出しているかに注目して考えてみましょう。
#
# 💡 **ヒント：** 講座の「1.5. よくある間違いと解決方法」にある「開始位置の間違い」の例を見返してみましょう。配列は何番目から始まるかがポイントです。
#
# <br>
#
# ## ステップ3：コードを修正して再実行しよう
#
# 修正したら、「コード」セルと「コンパイル＆実行」セルを**もう一度実行**してください。
# `コンパイル成功` と表示され、出力が期待する実行結果と一致すればOKです！
#
# <br>
#
# ## ステップ4：提出
#
# 正しい結果が確認できたら、「課題提出」セルを実行して提出してください。
#
# ⚠️ **注意：** エラーの行番号はファイル（main.c）の行番号です。セル上では先頭に `%%writefile main.c` の行があるため、**セル上の行番号はエラー表示より1行多く**なります。

# %%
# %%writefile main.c
# #include <stdio.h>
#
# int main() {
#     int sales[] = {1000, 1500, 2000, 1800, 1600, 2200, 1900};
#     int total = 0;
#     int i = 1;
#
#     printf("=== 売上集計開始 ===\n");
#     for (i = 1; i <= 7; i++) {
#         printf("%d日目の売上: %d円\n", i, sales[i]);
#         total += sales[i];
#     }
#     printf("週間合計: %d円\n", total);
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# # C_9 課題2 模範解答
#
# ### 問題点
# 1. 配列のインデックスが1から始まっているため、最初のデータ（sales[0]）が無視されます
# 2. `i <= 7`という条件により、存在しないsales[7]にアクセスしようとします
# 3. これにより、範囲外アクセスが発生し、不正な値が加算される可能性があります

# %%
# %%writefile main.c
# #include <stdio.h>
#
# int main() {
#     int sales[] = {1000, 1500, 2000, 1800, 1600, 2200, 1900};
#     int total = 0;
#     int i = 0;  // ★修正：初期値を1から0に変更
#
#     printf("=== 売上集計開始 ===\n");
#     for (i = 0; i < 7; i++) {  // ★修正：0始まりで7未満に変更
#         printf("%d日目の売上: %d円\n", i + 1, sales[i]);  // ★修正：表示用にi+1を使用
#         total += sales[i];
#     }
#     printf("週間合計: %d円\n", total);
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# ---
# # C_8 課題1
# この課題では、**if文・else if文の正しい書き方（条件式の記述ルール）** を確認します。
#
# 以下のコードは
# 1. 在庫数が0未満の場合 → 「在庫切れです」<br>
# 2. 在庫数が3未満の場合 → 「在庫が少なくなっています」<br>
# 3. 在庫数が3以上の場合 → 「在庫は十分です」<br>
#
# と表示するプログラムです
#
# **期待する実行結果：**
# ```
# 在庫は十分です
# ```
#
# 次のセルのプログラムにはエラーがあります。期待する実行結果になるよう、プログラムを修正してください。
#
# <br>
#
# ## ステップ1：まずそのまま実行してみよう
#
# 下の「%%writefile main.c」から始まる、プログラムが書かれているセルと「コンパイル＆実行」セルをそのまま実行してください。
# **コンパイルエラーが表示されます。**
#
# <br>
#
# ## ステップ2：エラーメッセージを読もう
#
# エラーメッセージには **何行目で何が問題か** が書かれています。
# 「expected（〜が期待される）」というメッセージが出たら、その行に何か書き忘れているということです。
#
# 💡 ヒント：講座の **セクション1.1「if文の基本形」** にあるコード例と、自分のコードの書き方を見比べてみましょう。
#
# <br>
#
# ## ステップ3：コードを修正して再実行しよう
#
# 修正したら、「コード」セルと「コンパイル＆実行」セルを **もう一度実行** してください。
# `コンパイル成功` と表示され、出力が `在庫は十分です` になればOKです！
#
# <br>
#
# ## ステップ4：提出
#
# 正しい結果が確認できたら、「課題提出」セルを実行して提出してください。
#
# ⚠️ **注意：** エラーの行番号はファイル（main.c）の行番号です。セル上では先頭に `%%writefile main.c` の行があるため、**セル上の行番号はエラー表示より1行多く**なります。

# %%
# %%writefile main.c
# #include <stdio.h>
#
# int main() {
#
#     int stock = 3;
#
#     if stock < 0 {
#         printf("在庫切れです\n");
#     } else if stock < 3 {
#         printf("在庫が少なくなっています\n");
#     } else
#         printf("在庫は十分です\n");
#
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# # C_8 課題1 模範解答
# 1. if文、else if文の条件式に括弧`()`がない
# 2. 条件式の後の波括弧`{}`がない

# %%
# %%writefile main.c
# #include <stdio.h>
#
# int main() {
#
#     int stock = 3;
#
#     if (stock < 0) {  // ★修正：条件式を()で囲む
#         printf("在庫切れです\n");
#     } else if (stock < 3) {  // ★修正：条件式を()で囲む
#         printf("在庫が少なくなっています\n");
#     } else {  // ★修正：elseの後に{を追加
#         printf("在庫は十分です\n");
#     }  // ★追加：elseブロックの閉じ括弧
#
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# # C_8 課題2
#
# この課題では、**switch文の正しい書き方（値による分岐のルール）** を確認します。
#
# 以下のコードは
# 1. `dept` が1の場合 → 「営業部」
# 2. `dept` が2の場合 → 「総務部」
# 3. `dept` が3の場合 → 「経理部」
# 4. 上記以外の場合 → 「その他」
#
# と表示するプログラムです。
#
# **期待する実行結果：**
# ```
# 総務部
# ```
#
# 次のセルのプログラムにはエラーがあります。期待する実行結果になるよう、プログラムを修正してください。
#
# <br>
#
# ## ステップ1：まずそのまま実行してみよう
#
# 下の「%%writefile main.c」から始まる、プログラムが書かれているセルと「コンパイル＆実行」セルをそのまま実行してください。
# **コンパイルエラーが表示されます。**
#
# <br>
#
# ## ステップ2：エラーメッセージを読もう
#
# エラーメッセージには **何行目で何が問題か** が書かれています。
# エラーが複数表示される場合は、**一番上のエラーから順番に対処**しましょう。1つ直すと他のエラーも消えることがあります。
#
# 💡 ヒント：講座の **セクション2「switch文」** にあるコード例や説明文と、自分のコードを見比べてみましょう。
#
# <br>
#
# ## ステップ3：コードを修正して再実行しよう
#
# 修正したら、「コード」セルと「コンパイル＆実行」セルを **もう一度実行** してください。
# `コンパイル成功` と表示され、出力が `総務部` になればOKです！
#
# <br>
#
# ## ステップ4：提出
#
# 正しい結果が確認できたら、「課題提出」セルを実行して提出してください。
#
# ⚠️ **注意：** エラーの行番号はファイル（main.c）の行番号です。セル上では先頭に `%%writefile main.c` の行があるため、**セル上の行番号はエラー表示より1行多く**なります。

# %%
# %%writefile main.c
# #include <stdio.h>
#
# int main() {
#
#     int dept = 2;
#
#     switch dept {
#         case 1:
#             printf("営業部\n");
#         case 2:
#             printf("総務部\n");
#         case 3:
#             printf("経理部\n");
#         default:
#             printf("その他\n");
#     }
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# # C_8 課題2 模範解答
# 1. switch文の条件式には()が必要
# 2. 各caseの後には`break`が必要（ないと通常のコードでは次のcaseも実行される）

# %%
# %%writefile main.c
# #include <stdio.h>
#
# int main() {
#
#     int dept = 2;
#
#     switch (dept) {  // ★修正：条件式を()で囲む
#         case 1:
#             printf("営業部\n");
#             break;  // ★追加：フォールスルー防止のためbreakを追加
#         case 2:
#             printf("総務部\n");
#             break;  // ★追加：フォールスルー防止のためbreakを追加
#         case 3:
#             printf("経理部\n");
#             break;  // ★追加：フォールスルー防止のためbreakを追加
#         default:
#             printf("その他\n");
#             break;  // ★追加：defaultにもbreakを追加
#     }
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# ---
# # C_10 課題1
#
# この課題では、**構造体のメンバへのアクセス（ドット `.` を使って構造体の中のデータを取り出すこと）** と **printf の書式指定子への値の渡し方** を確認します。
#
# 次のセルのプログラムは3人の学生情報を管理するプログラムです。
#
# **期待する実行結果：**
# ```
# 【学生情報一覧】
#
# 1人目の学生
# 名前：田中太郎
# 学年：2年
# 成績：85.5点
#
# 2人目の学生
# 名前：山田花子
# 学年：1年
# 成績：92.0点
#
# 3人目の学生
# 名前：佐藤一郎
# 学年：3年
# 成績：78.5点
#
# 全体の平均点：85.3点
# ```
#
# 次のセルのプログラムにはエラーがあります。期待する実行結果になるよう、プログラムを修正してください。
#
# <br>
#
# ## ステップ1：まずそのまま実行してみよう
#
# 下の `%%writefile main.c` から始まる、プログラムが書かれているセルと「コンパイル＆実行」セルをそのまま実行してください。
# **コンパイルエラーが表示されます。**
#
# <br>
#
# ## ステップ2：エラーメッセージを読もう
#
# 表示されたエラーメッセージを読んでみましょう。
# エラーメッセージには **何行目で何が問題か** が書かれています（英語ですが、要点は「データの型に対応する値が足りない」という意味です）。
#
# 💡 ヒント：講座の「**3．構造体変数の宣言と使い方**」のコード例で、`printf` に構造体のメンバをどう渡しているかを見返してみましょう。
#
# <br>
#
# ## ステップ3：コードを修正して再実行しよう
#
# 修正したら、「コード」セルと「コンパイル＆実行」セルを**もう一度実行**してください。
# `コンパイル成功` と表示され、期待する実行結果と同じ出力が出ればOKです！
#
# <br>
#
# ## ステップ4：提出
#
# 正しい結果が確認できたら、「課題提出」セルを実行して提出してください。
#
# <br>
#
# ⚠️ **注意：** エラーの行番号はファイル（main.c）の行番号です。セル上では先頭に `%%writefile main.c` の行があるため、**セル上の行番号はエラー表示より1行多く**なります。

# %%
# %%writefile main.c
# # include <stdio.h>
# # include <string.h>
#
# typedef struct {
#     char name[50];
#     int grade;
#     float score;
# } Student;
#
# int main() {
#     // 3人の学生データを作成
#     Student students[3] = {
#         {"田中太郎", 2, 85.5},
#         {"山田花子", 1, 92.0},
#         {"佐藤一郎", 3, 78.5}
#     };
#
#     // 全員の情報を表示
#     printf("【学生情報一覧】\n");
#     for(int i = 0; i < 3; i++) {
#         printf("\n%d人目の学生\n", i+1);
#         printf("名前：%s\n");
#         printf("学年：%d年\n");
#         printf("成績：%.1f点\n");
#     }
#
#     // 平均点を計算
#     float sum = 0;
#     for(int i = 0; i < 3; i++) {
#         sum += students[i].score;
#     }
#     float average = sum / 3;
#
#     printf("\n全体の平均点：%.1f点\n", average);
#
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# # C_10 課題1 模範解答
# 1. 構造体のデータを表示する箇所が無い。それぞれstudents[i].name, students[i].grade, students[i].scoreでアクセスする。

# %%
# %%writefile main.c
# # include <stdio.h>
# # include <string.h>
#
# typedef struct {
#     char name[50];
#     int grade;
#     float score;
# } Student;
#
# int main() {
#     // 3人の学生データを作成
#     Student students[3] = {
#         {"田中太郎", 2, 85.5},
#         {"山田花子", 1, 92.0},
#         {"佐藤一郎", 3, 78.5}
#     };
#
#     // 全員の情報を表示
#     printf("【学生情報一覧】\n");
#     for(int i = 0; i < 3; i++) {
#         printf("\n%d人目の学生\n", i+1);
#         printf("名前：%s\n", students[i].name);  // ★修正：第2引数に構造体メンバーを指定
#         printf("学年：%d年\n", students[i].grade);  // ★修正：第2引数に構造体メンバーを指定
#         printf("成績：%.1f点\n", students[i].score);  // ★修正：第2引数に構造体メンバーを指定
#     }
#
#     // 平均点を計算
#     float sum = 0;
#     for(int i = 0; i < 3; i++) {
#         sum += students[i].score;
#     }
#     float average = sum / 3;
#
#     printf("\n全体の平均点：%.1f点\n", average);
#
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# ---
# # C_11 課題1
#
# この課題では、**ポインタ（アドレスを格納する変数）** を使って変数の値を表示・変更する方法を確認します。
#
# 次のセルのプログラムは、変数のアドレスをポインタに格納し、ポインタ経由で値を変更するプログラムです。<br>
#
# **期待する実行結果：**
# ```
# 変数の値: 15
# 変数のアドレス: 0x7fff5fbff6bc  ※アドレスは環境によって異なります
# ポインタの指す値: 15
# 値を変更しました
# 変数の新しい値: 30
# ```
#
# 次のセルのプログラムは未完成です。期待する実行結果になるよう、プログラムを完成させてください。
#
# <br>
#
# ## ステップ1：まずそのまま実行してみよう
#
# 下の「%%writefile main.c」から始まる、プログラムが書かれているセルと「コンパイル＆実行」セルをそのまま実行してください。
# **コンパイルエラーが表示されます。**
#
# <br>
#
# ## ステップ2：エラーメッセージを読もう
#
# 表示されたエラーメッセージを読んでみましょう。エラーメッセージには**何行目で何が問題か**が書かれています。
#
# - `error: expected expression`（式が必要です）→ 何かを書くべき場所が空になっています
# - `error: use of undeclared identifier`（宣言されていない名前が使われています）→ 必要な変数がまだ宣言されていません
#
# 💡 ヒント：講座の「2.1. ポインタの役割」セクションにある、ポインタの宣言・アドレス演算子（&）・間接参照演算子（*）の使い方を見返してみましょう。
#
# <br>
#
# ## ステップ3：コードを修正して再実行しよう
#
# 修正したら、「コード」セルと「コンパイル＆実行」セルを**もう一度実行**してください。
# `コンパイル成功` と表示され、期待する実行結果と同じ出力になればOKです！
#
# <br>
#
# ## ステップ4：提出
#
# 正しい結果が確認できたら、「課題提出」セルを実行して提出してください。
#
# <br>
#
# ⚠️ **注意：** エラーの行番号はファイル（main.c）の行番号です。セル上では先頭に `%%writefile main.c` の行があるため、**セル上の行番号はエラー表示より1行多く**なります。

# %%
# %%writefile main.c
# #include <stdio.h>
#
# int main() {
#     // 変数の宣言と初期化
#     int value = 15;
#
#     // TODO 1: int型ポインタptrを宣言し、NULLで初期化してください
#
#
#     // TODO 2: ポインタに変数valueのアドレスを代入してください
#
#
#     // 変数の値とアドレスを表示
#     printf("変数の値: %d\n", value);
#     printf("変数のアドレス: %p\n", (void*)&value);
#
#     printf("ポインタの指す値: %d\n", );   // TODO 3: ポインタが指す値を表示してください
#
#     // TODO 4: ポインタを使って変数の値を30に変更してください
#
#
#     printf("値を変更しました\n");
#     printf("変数の新しい値: %d\n", value);
#
#     return 0;
# }

# %%
# コンパイル＆実行
if compile_program():
    run_program()

# %% [markdown]
# # C_11 課題1 模範解答
#
# 1. int *ptr = NULL;
#    - int型のポインタを宣言し、安全のためNULLで初期化します
#
# 2. ptr = &value;
#    - アドレス演算子(&)を使って変数valueのアドレスを取得し、
#      ポインタptrに格納します
#
# 3. *ptrで間接参照し、ポインタが指す先の値を表示します
#
# 4. *ptr = 30;
#    - 間接参照演算子(*)を使ってポインタが指す先の値を
#      30に変更します
#
#
# ※ アドレスを表示する場合、アドレスをvoid型でキャストし、%pで16進数として表示します

# %%
# %%writefile main.c
# #include <stdio.h>
#
# int main() {
#     // 変数の宣言と初期化
#     int value = 15;
#
#     // TODO 1: int型ポインタを宣言し、NULLで初期化
#     int *ptr = NULL;  // ★追加：int型ポインタをNULLで初期化
#
#     // TODO 2: ポインタに変数valueのアドレスを代入
#     ptr = &value;  // ★追加：&演算子でvalueのアドレスを代入
#
#     // 変数の値とアドレスを表示
#     printf("変数の値: %d\n", value);
#     printf("変数のアドレス: %p\n", (void*)&value);
#
#     // TODO 3: ポインタが指す値を表示
#     printf("ポインタの指す値: %d\n", *ptr);  // ★修正：*ptrでポインタが指す値を表示
#
#     // TODO 4: ポインタを使って変数の値を30に変更
#     *ptr = 30;  // ★追加：*ptrを通じてvalueの値を30に変更
#
#     printf("値を変更しました\n");
#     printf("変数の新しい値: %d\n", value);
#
#     return 0;
# }

# %%
# コンパイル＆実行
if compile_program():
    run_program()

# %% [markdown]
# ---
# # C_12 課題1
#
#
# この課題では、**アドレス渡し（変数のメモリアドレスを関数に渡す方法）** を使って、関数から呼び出し元の変数を変更する方法を確認します。
#
# 次のセルのプログラムは、2つの整数値を交換して表示するプログラムです。<br>
#
# **期待する実行結果：**
# ```
# 交換後:
# num1 = 20
# num2 = 10
# ```
#
# 次のセルのプログラムにはエラーがあります。期待する実行結果になるよう、プログラムを修正してください。
#
# <br>
#
# ## ステップ1：まずそのまま実行してみよう
#
# 下の `%%writefile main.c` から始まる、プログラムが書かれているセルと「コンパイル＆実行」セルをそのまま実行してください。
# **コンパイルエラーが表示されます。**
#
# <br>
#
# ## ステップ2：エラーメッセージを読もう
#
# エラーメッセージには、**何行目で何が問題か**が書かれています。
# 英語で表示されますが、たとえば `expected expression`（式が必要です）は「= の右側に何も書かれていない」ことを意味します。
# 空欄になっている箇所をすべて見つけましょう。
#
# 💡 ヒント：講座の「2.2 アドレス渡しの例」にある swap に似た処理の流れと、課題文中の「swap関数内の処理」の3ステップを見返してみましょう。
#
# <br>
#
# ## ステップ3：コードを修正して再実行しよう
#
# 修正したら、「コード」セルと「コンパイル＆実行」セルを**もう一度実行**してください。
# `コンパイル成功` と表示され、出力が以下のようになればOKです！
# ```
# 交換後:
# num1 = 20
# num2 = 10
# ```
#
# <br>
#
# ## ステップ4：提出
#
# 正しい結果が確認できたら、「課題提出」セルを実行して提出してください。
#
# <br>
#
# ⚠️ **注意：** エラーの行番号はファイル（main.c）の行番号です。セル上では先頭に `%%writefile main.c` の行があるため、**セル上の行番号はエラー表示より1行多く**なります。

# %%
# %%writefile main.c
# #include <stdio.h>
#
# // この関数を修正して、2つの値を正しく交換できるようにしてください
# void swap(int* x, int* y) {
#     int temp = ;
#     x = ;
#     y = ;
# }
#
# int main() {
#     int num1 = 10;
#     int num2 = 20;
#
#     // 値の交換を試みる
#     swap(); // 修正してください
#
#     // 交換後の値を表示
#     printf("\n交換後:\n");
#     printf("num1 = %d\n", num1);
#     printf("num2 = %d\n", num2);
#
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# # C_12 課題1 模範解答
#
#
# エラーの理由：
# 1. `swap`関数の引数が指定されていません。`swap()`の括弧内に`&num1, &num2`を渡す必要があります。
# 2. `swap`関数内でポインタの値を直接代入しようとしています。ポインタが指す値（*x, *y）を操作する必要があります。
# 3. `temp`変数の初期値が未設定です。一時的な保存用に`*x`の値を代入する必要があります。

# %%
# %%writefile main.c
# #include <stdio.h>
#
# // この関数を修正して、2つの値を正しく交換できるようにしてください
# void swap(int* x, int* y) {
#     int temp = *x;  // ★修正：*xで参照先の値をtempに保存
#     *x = *y;  // ★修正：*yの値を*xに代入
#     *y = temp;  // ★修正：tempの値を*yに代入
# }
#
# int main() {
#     int num1 = 10;
#     int num2 = 20;
#
#     // 値の交換を試みる
#     swap(&num1, &num2);  // ★修正：&演算子でアドレスを渡す
#
#     printf("\n交換後:\n");
#     printf("num1 = %d\n", num1);
#     printf("num2 = %d\n", num2);
#
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# ---
# # C_12 課題2
# この課題では、**構造体のアドレス渡し（構造体のポインタを関数に渡して、中身を直接変更する方法）** を確認します。
#
# 次のセルのプログラムは、社員の給与を更新して表示するプログラムです。<br>
#
# **期待する実行結果：**
# ```
# 更新前の給与: 250000
# updateSalaryの給与: 280000
# 更新後の給与: 280000
# ```
#
# 次のセルのプログラムにはエラーがあります。期待する実行結果になるよう、プログラムを修正してください。
#
# <br>
#
# ## ステップ1：まずそのまま実行してみよう
#
# 下の `%%writefile main.c` から始まる、プログラムが書かれているセルと「コンパイル＆実行」セルをそのまま実行してください。
# コンパイルは成功しますが、**実行結果が期待と違う**はずです。どこが違うか見比べてみましょう。
#
# <br>
#
# ## ステップ2：出力結果を見比べよう
#
# 出力結果と期待する実行結果を見比べて、どの行の値が違うかを見つけてください。
# 「関数の中では値が変わっているのに、関数の外では変わらない」のはなぜか考えてみましょう。
#
# 💡 ヒント：講座の「1. 値渡し」と「2. アドレス渡し」の違い、および「4.2 基本的な使い方」「4.3 アロー演算子」のセクションを見返してみましょう。
#
# <br>
#
# ## ステップ3：コードを修正して再実行しよう
#
# 修正したら、「コード」セルと「コンパイル＆実行」セルを**もう一度実行**してください。
# `コンパイル成功` と表示され、出力が以下のようになればOKです！
# ```
# 更新前の給与: 250000
# updateSalaryの給与: 280000
# 更新後の給与: 280000
# ```
#
# <br>
#
# ## ステップ4：提出
#
# 正しい結果が確認できたら、「課題提出」セルを実行して提出してください。

# %%
# %%writefile main.c
# #include <stdio.h>
#
# typedef struct {
#     char name[20];
#     int salary;
# }Employee;
#
# // この関数を修正してください
# void updateSalary(Employee emp, int newSalary) {
#
#     emp.salary = newSalary;  // この行が正しく動作しません
#     printf("updateSalaryの給与: %d\n", emp.salary);
#
# }
#
# int main() {
#     Employee emp1 = {"山田", 250000};
#
#     printf("更新前の給与: %d\n", emp1.salary);
#
#     updateSalary(emp1, 280000);
#
#     printf("更新後の給与: %d\n", emp1.salary);
#
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# # C_12 課題2 模範解答
#
# ## エラーの理由：
# 1. `updateSalary`関数の引数`emp`は、構造体のコピーとして渡されているため、関数内での変更が元のデータに反映されません。
# 2. 構造体のデータを更新するためには、アドレスを渡す必要があります。

# %%
# %%writefile main.c
# #include <stdio.h>
#
# typedef struct {
#     char name[20];
#     int salary;
# }Employee;
#
# // この関数を修正してください
# void updateSalary(Employee *emp, int newSalary) {  // ★修正：Employee型をポインタ渡しに変更
#
#     emp->salary = newSalary;  // ★修正：アロー演算子(->)でポインタ経由のアクセス
#     printf("updateSalaryの給与: %d\n", emp->salary);  // ★修正：アロー演算子に変更
#
# }
#
# int main() {
#     Employee emp1 = {"山田", 250000};
#
#     printf("更新前の給与: %d\n", emp1.salary);
#
#     updateSalary(&emp1, 280000);  // ★修正：&演算子でアドレスを渡す
#
#     printf("更新後の給与: %d\n", emp1.salary);
#
#     return 0;
# }

# %%
if compile_program():
    run_program()

# %% [markdown]
# ---
# # C_13 課題1
#
# この課題では、**境界値テスト（値の切り替わり付近を重点的に試すテスト）** を自分で設計し、プログラムのバグを見つけて修正します。
#
# この課題は、これまでの課題と進め方が異なります。
# **「テストケースを自分で考える → 実行してバグを見つける → コードを修正する」** という流れで進めます。
#
# <br>
#
# ## 今回のテストの考え方
#
# 今回は **ブラックボックステスト** を行います。プログラムの中身は見ずに、入力（西暦）に対する出力（和暦）が正しいかだけを確認します。
#
# テストケースの選び方は **境界値テスト** の考え方を使います。
# - 元号が切り替わる年は、プログラムが間違いやすいポイントです
# - 「4.2. 対応している年号と期間」の表を見て、各元号の **始まりの年** と **その前の年** に注目してみましょう
# - それ以外に、通常のケースや範囲外のケースも入れておくと安心です
#
# <br>
#
# ## ステップ1：テストケースを自分で考えて作成しよう
#
# 上の「テストケース作成」セル（`%%writefile test_cases.txt`）を編集して、テストしたい西暦を **1行に1つずつ** 書いてください。
#
# バグを見つけるには、どの年を試せばよいでしょうか？
#
# 「4.2. 対応している年号と期間」の表と、上の境界値テストの考え方を参考に、自分でテストケースを選んでみましょう。
#
# 編集できたら、そのセルを実行してファイルを保存してください。
#
# <br>
#
# ## ステップ2：プログラムを実行して出力結果を確認しよう
#
# 「テストケース作成」セルを実行した後、「コンパイル＆実行」セルを実行してください。
# コンパイルは成功しますが、**一部の年で変換結果がおかしい**はずです。
#
# 出力された結果を見て、**どの年の変換が間違っているか** を見つけてください。
#
# 正しい和暦がわからないときは「4.2. 対応している年号と期間」の表と照らし合わせてみましょう。
#
# <br>
#
# ## ステップ3：コードを修正して再実行しよう
#
# どの年が間違っているかわかったら、「西暦年号変換プログラム本体」セルの中のコードを修正してください。
#
# 💡 ヒント：「4.2. 対応している年号と期間」の表に書かれた各元号の範囲と、プログラムの `calculateEra` 関数内の条件式を見比べてみましょう。
#
# 修正したら、「西暦年号変換プログラム本体」セルと「コンパイル＆実行」セルを **もう一度実行** してください。
# `コンパイル成功` と表示され、すべての年が正しく変換されればOKです！
#
# <br>
#
# ## ステップ4：提出
#
# 正しい結果が確認できたら、「課題提出」セルを実行して提出してください。

# %%
# テストケース作成
# %%writefile test_cases.txt
2024
2023

# %%
#@title 西暦年号変換プログラム本体 { display-mode: "form"}

# %%writefile main.c
#include <stdio.h>
#include <string.h>
#include <stdlib.h>
#include <ctype.h>

// 定数の定義
#define REIWA_START 2019
#define HEISEI_START 1989
#define SHOWA_START 1926
#define TAISHO_START 1912
#define MEIJI_START 1868
#define ERA_NAME_LENGTH 8
#define MAX_TESTS 100

// 元号を表す構造体
typedef struct {
    char eraName[ERA_NAME_LENGTH];
    int eraYear;
} Era;

// 文字列が有効な数値かチェックする関数
int isValidNumber(const char* str) {
    // 空文字列チェック
    if (str[0] == '\n' || str[0] == '\0') {
        return 0;
    }

    // 各文字をチェック
    for (int i = 0; str[i] != '\0' && str[i] != '\n'; i++) {
        if (!isdigit(str[i])) {
            return 0;
        }
    }
    return 1;
}

// 元号と和暦年を一度に計算する関数
void calculateEra(int year, Era* era) {
    if (year >= REIWA_START) {
        strcpy(era->eraName, "令和");
        era->eraYear = year - REIWA_START + 1;
    } else if (year > HEISEI_START) {
        strcpy(era->eraName, "平成");
        era->eraYear = year - HEISEI_START + 1;
    } else if (year >= SHOWA_START) {
        strcpy(era->eraName, "昭和");
        era->eraYear = year - SHOWA_START + 1;
    } else if (year >= TAISHO_START) {
        strcpy(era->eraName, "大正");
        era->eraYear = year - TAISHO_START + 1;
    } else if (year >= MEIJI_START) {
        strcpy(era->eraName, "明治");
        era->eraYear = year - MEIJI_START + 1;
    } else {
        strcpy(era->eraName, "不明");
        era->eraYear = 0;
    }
}

int main() {
    FILE *fp;
    char line[256];
    int numTests = 0;
    Era era;

    // テストケースファイルを開く
    fp = fopen("test_cases.txt", "r");
    if (fp == NULL) {
        printf("テストケースファイルを開けませんでした。\n");
        return 1;
    }

    printf("和暦変換テストを開始します\n");
    printf("----------------------------\n");

    // ファイルから年を読み込み、変換する
    while (fgets(line, sizeof(line), fp) && numTests < MAX_TESTS) {
        if (!isValidNumber(line)) {
            printf("無効な入力（行 %d）: %s", numTests + 1, line);
            continue;
        }

        int year = atoi(line);
        calculateEra(year, &era);

        printf("西暦%d年 -> ", year);
        if (strcmp(era.eraName, "不明") != 0) {
            if (era.eraYear == 1) {
                printf("%s元年\n", era.eraName);
            } else {
                printf("%s%d年\n", era.eraName, era.eraYear);
            }
        } else {
            printf("対応していない年代です\n");
        }
        numTests++;
    }

    fclose(fp);
    printf("----------------------------\n");
    printf("テスト完了（有効なテストケース: %d件）\n", numTests);

    return 0;
}

# %%
if compile_program():
    run_program()

# %% [markdown]
# # C_13 課題1 模範解答
#
# 修正のポイント：
#
#
# まず、テストケースには境界値を含めるとして、推奨テストケースは以下のとおりです（test_cases.txt）：
# ```
# 2026
# 2019
# 2018
# 1989
# 1988
# 1926
# 1925
# 1912
# 1911
# 1868
# 1867
# ```
# これを実施すると、以下の通り表示されます
#
# > 和暦変換テストを開始します<br>
# ----------------------------<br>
# 西暦2024年 -> 令和6年<br>
# 西暦2019年 -> 令和元年<br>
# 西暦2018年 -> 平成30年<br>
# 西暦1989年 -> 昭和64年<br>
# 西暦1988年 -> 昭和63年<br>
# 西暦1926年 -> 昭和元年<br>
# 西暦1925年 -> 大正14年<br>
# 西暦1912年 -> 大正元年<br>
# 西暦1911年 -> 明治44年<br>
# 西暦1868年 -> 明治元年<br>
# 西暦1867年 -> 対応していない年代です<br>
# ----------------------------
# テスト完了（有効なテストケース: 11件）
#
# 西暦1989年 -> 平成元年　が期待値ですが、<br>
# 西暦1989年 -> 昭和64年<br>
# と表示されます。<br><br>
# 他の箇所は、想定どおりです。<br>
# つまり、プログラムで平成の始まりを判定する箇所にバグがあるようです。
# <br><br>
#
# calculateEra関数を見てみると、`else if (year > HEISEI_START) {`という条件式で平成年代を判定しています。これでは1989年は平成に当てはまらず、常に昭和と判断されます。`>=`に修正する必要があります。
#
#
# 具体的な修正箇所：
# ```c
# // 修正前
# } else if (year > HEISEI_START) {
#     strcpy(era->eraName, "平成");
#     era->eraYear = year - HEISEI_START + 1;
#
# // 修正後
# } else if (year >= HEISEI_START) {
#     strcpy(era->eraName, "平成");
#     era->eraYear = year - HEISEI_START + 1;
# ```

# %%
# テストケース作成
# %%writefile test_cases.txt
2026
2019
2018
1989
1988
1926
1925
1912
1911
1868
1867

# %%
#@title 西暦年号変換プログラム本体 { display-mode: "form"}

# %%writefile main.c
#include <stdio.h>
#include <string.h>
#include <stdlib.h>
#include <ctype.h>

// 定数の定義
#define REIWA_START 2019
#define HEISEI_START 1989
#define SHOWA_START 1926
#define TAISHO_START 1912
#define MEIJI_START 1868
#define ERA_NAME_LENGTH 8
#define MAX_TESTS 100

// 元号を表す構造体
typedef struct {
    char eraName[ERA_NAME_LENGTH];
    int eraYear;
} Era;

// 文字列が有効な数値かチェックする関数
int isValidNumber(const char* str) {
    // 空文字列チェック
    if (str[0] == '\n' || str[0] == '\0') {
        return 0;
    }

    // 各文字をチェック
    for (int i = 0; str[i] != '\0' && str[i] != '\n'; i++) {
        if (!isdigit(str[i])) {
            return 0;
        }
    }
    return 1;
}

// 元号と和暦年を一度に計算する関数
void calculateEra(int year, Era* era) {
    if (year >= REIWA_START) {
        strcpy(era->eraName, "令和");
        era->eraYear = year - REIWA_START + 1;
    } else if (year >= HEISEI_START) {  // ★修正：>を>=に変更（1989年を平成に含める）
        strcpy(era->eraName, "平成");
        era->eraYear = year - HEISEI_START + 1;
    } else if (year >= SHOWA_START) {
        strcpy(era->eraName, "昭和");
        era->eraYear = year - SHOWA_START + 1;
    } else if (year >= TAISHO_START) {
        strcpy(era->eraName, "大正");
        era->eraYear = year - TAISHO_START + 1;
    } else if (year >= MEIJI_START) {
        strcpy(era->eraName, "明治");
        era->eraYear = year - MEIJI_START + 1;
    } else {
        strcpy(era->eraName, "不明");
        era->eraYear = 0;
    }
}

int main() {
    FILE *fp;
    char line[256];
    int numTests = 0;
    Era era;

    // テストケースファイルを開く
    fp = fopen("test_cases.txt", "r");
    if (fp == NULL) {
        printf("テストケースファイルを開けませんでした。\n");
        return 1;
    }

    printf("和暦変換テストを開始します\n");
    printf("----------------------------\n");

    // ファイルから年を読み込み、変換する
    while (fgets(line, sizeof(line), fp) && numTests < MAX_TESTS) {
        if (!isValidNumber(line)) {
            printf("無効な入力（行 %d）: %s", numTests + 1, line);
            continue;
        }

        int year = atoi(line);
        calculateEra(year, &era);

        printf("西暦%d年 -> ", year);
        if (strcmp(era.eraName, "不明") != 0) {
            if (era.eraYear == 1) {
                printf("%s元年\n", era.eraName);
            } else {
                printf("%s%d年\n", era.eraName, era.eraYear);
            }
        } else {
            printf("対応していない年代です\n");
        }
        numTests++;
    }

    fclose(fp);
    printf("----------------------------\n");
    printf("テスト完了（有効なテストケース: %d件）\n", numTests);

    return 0;
}

# %%
if compile_program():
    run_program()

# %% [markdown]
# ---
# # C_14 課題1
#
# ### 課題の概要
#
# この課題では、**#include（ファイルを連結する仕組み）** が正しく使われているかを確認します。
#
# 以下は、西暦年号変換プログラムを3つのファイルに分割した例です。
#
# <br>
#
# 構成：<br>
# ┝ convert.h<br>
# ┝ convert.c<br>
# └ main.c
#
# <br>
#
# **期待する実行結果：**
# ```
# 和暦変換テストを開始します
# ----------------------------
# 西暦2024年 -> 令和6年
# 西暦2019年 -> 令和元年
# 西暦2018年 -> 平成30年
# ----------------------------
# テスト完了（有効なテストケース: 3件）
# ```
#
# 次のセルのプログラムにはエラーがあります。期待する実行結果になるよう、プログラムを修正してください。
#
# <br>
#
# ## ステップ1：まずそのまま実行してみよう
#
# 「convert.h」「convert.c」「main.c」の各セルと「コンパイル＆実行」セルを、修正せずにそのまま実行してください。
# **コンパイルエラーが表示されます。**
#
# <br>
#
# ## ステップ2：エラーメッセージを読もう
#
# エラーメッセージには、**何行目で何が問題か**が書かれています。
# 「unknown type name（不明な型名）」や「implicit declaration of function（関数が宣言されていない）」のようなメッセージが出た場合、そのファイルに必要な情報が伝わっていないことを意味します。
#
# 💡 ヒント：講座のセクション2.3「ファイルの連結（#include）」とセクション2.4「インクルードの書き方」を見返してみましょう。
#
# <br>
#
# ## ステップ3：コードを修正して再実行しよう
#
# 修正したら、各セルと「コンパイル＆実行」セルを**もう一度実行**してください。
# `コンパイル成功` と表示され、期待する実行結果が出ればOKです！
#
# <br>
#
# ## ステップ4：提出
#
# 正しい結果が確認できたら、「課題提出」セルを実行して提出してください。
#
# <br>
#
# ⚠️ **注意：** エラーの行番号はファイル（main.c）の行番号です。セル上では先頭に `%%writefile main.c` の行があるため、**セル上の行番号はエラー表示より1行多く**なります。

# %%
# テストケース作成
# %%writefile test_cases.txt
2024
2019
2018

# %%
# %%writefile convert.h
# // convert.h
# #pragma once
#
# // 定数の定義
# #define ERA_NAME_LENGTH 8
#
# // 元号を表す構造体
# typedef struct {
#     char eraName[ERA_NAME_LENGTH];
#     int eraYear;
# } Era;
#
# // 関数のプロトタイプ宣言
# void calculateEra(int year, Era* era);
# int isValidNumber(const char* str);

# %%
# %%writefile convert.c
# // convert.c
# #include <string.h>
# #include <ctype.h>
# #include "convert.h"
#
# // 内部定数の定義（外部からは参照できない）
# static const int REIWA_START = 2019;
# static const int HEISEI_START = 1989;
# static const int SHOWA_START = 1926;
# static const int TAISHO_START = 1912;
# static const int MEIJI_START = 1868;
#
# void calculateEra(int year, Era* era) {
#     if (year >= REIWA_START) {
#         strcpy(era->eraName, "令和");
#         era->eraYear = year - REIWA_START + 1;
#     } else if (year >= HEISEI_START) {
#         strcpy(era->eraName, "平成");
#         era->eraYear = year - HEISEI_START + 1;
#     } else if (year >= SHOWA_START) {
#         strcpy(era->eraName, "昭和");
#         era->eraYear = year - SHOWA_START + 1;
#     } else if (year >= TAISHO_START) {
#         strcpy(era->eraName, "大正");
#         era->eraYear = year - TAISHO_START + 1;
#     } else if (year >= MEIJI_START) {
#         strcpy(era->eraName, "明治");
#         era->eraYear = year - MEIJI_START + 1;
#     } else {
#         strcpy(era->eraName, "不明");
#         era->eraYear = 0;
#     }
# }
#
# int isValidNumber(const char* str) {
#     // 空文字列チェック
#     if (str[0] == '\n' || str[0] == '\0') {
#         return 0;
#     }
#
#     // 各文字をチェック
#     for (int i = 0; str[i] != '\0' && str[i] != '\n'; i++) {
#         if (!isdigit(str[i])) {
#             return 0;
#         }
#     }
#     return 1;
# }

# %%
# %%writefile main.c
# // main.c
# #include <stdio.h>
# #include <stdlib.h>
# #include <string.h>
#
# #define MAX_TESTS 100
#
# int main() {
#     FILE *fp;
#     char line[256];
#     int numTests = 0;
#     Era era;
#
#     // テストケースファイルを開く
#     fp = fopen("test_cases.txt", "r");
#     if (fp == NULL) {
#         printf("テストケースファイルを開けませんでした。\n");
#         return 1;
#     }
#
#     printf("和暦変換テストを開始します\n");
#     printf("----------------------------\n");
#
#     // ファイルから年を読み込み、変換する
#     while (fgets(line, sizeof(line), fp) && numTests < MAX_TESTS) {
#         if (!isValidNumber(line)) {
#             printf("無効な入力（行 %d）: %s", numTests + 1, line);
#             continue;
#         }
#
#         int year = atoi(line);
#         calculateEra(year, &era);
#
#         printf("西暦%d年 -> ", year);
#         if (strcmp(era.eraName, "不明") != 0) {
#             if (era.eraYear == 1) {
#                 printf("%s元年\n", era.eraName);
#             } else {
#                 printf("%s%d年\n", era.eraName, era.eraYear);
#             }
#         } else {
#             printf("対応していない年代です\n");
#         }
#         numTests++;
#     }
#
#     fclose(fp);
#     printf("----------------------------\n");
#     printf("テスト完了（有効なテストケース: %d件）\n", numTests);
#
#     return 0;
# }

# %%
# コンパイル＆実行
if compile_program():
    run_program()

# %% [markdown]
# # C_14 課題1 模範解答
#
# 修正のポイント：
#
# 1. main.cファイルに `#include "convert.h"` が欠けています。このヘッダーファイルには必要な関数と構造体の宣言が含まれています。
#
# 2. 具体的なエラーは以下のようになります：
#    - `Era`構造体の定義が見つからない
#    - `isValidNumber()`関数の定義が見つからない
#    - `calculateEra()`関数の定義が見つからない
#
# 3. なぜエラーが発生するのか：
#    - C言語ではソースファイル間で関数や型を使用するには、それらの宣言を含むヘッダーファイルをインクルードする必要があります
#    - `convert.h`には`Era`構造体の定義と、`isValidNumber()`および`calculateEra()`関数のプロトタイプ宣言が含まれています
#    - main.cでこれらを使用するには、`convert.h`をインクルードして定義を参照可能にする必要があります
#
# 4. 修正方法：
#    - main.cの先頭の`#include`部分に`#include "convert.h"`を追加します
#    - これにより、convert.hで定義された構造体や関数をmain.cから使用できるようになります

# %%
# テストケース作成
# %%writefile test_cases.txt
2024
2019
2018

# %%
# %%writefile convert.h
# // convert.h
# #pragma once
#
# // 定数の定義
# #define ERA_NAME_LENGTH 8
#
# // 元号を表す構造体
# typedef struct {
#     char eraName[ERA_NAME_LENGTH];
#     int eraYear;
# } Era;
#
# // 関数のプロトタイプ宣言
# void calculateEra(int year, Era* era);
# int isValidNumber(const char* str);

# %%
# %%writefile convert.c
# // convert.c
# #include <string.h>
# #include <ctype.h>
# #include "convert.h"
#
# // 内部定数の定義（外部からは参照できない）
# static const int REIWA_START = 2019;
# static const int HEISEI_START = 1989;
# static const int SHOWA_START = 1926;
# static const int TAISHO_START = 1912;
# static const int MEIJI_START = 1868;
#
# void calculateEra(int year, Era* era) {
#     if (year >= REIWA_START) {
#         strcpy(era->eraName, "令和");
#         era->eraYear = year - REIWA_START + 1;
#     } else if (year >= HEISEI_START) {
#         strcpy(era->eraName, "平成");
#         era->eraYear = year - HEISEI_START + 1;
#     } else if (year >= SHOWA_START) {
#         strcpy(era->eraName, "昭和");
#         era->eraYear = year - SHOWA_START + 1;
#     } else if (year >= TAISHO_START) {
#         strcpy(era->eraName, "大正");
#         era->eraYear = year - TAISHO_START + 1;
#     } else if (year >= MEIJI_START) {
#         strcpy(era->eraName, "明治");
#         era->eraYear = year - MEIJI_START + 1;
#     } else {
#         strcpy(era->eraName, "不明");
#         era->eraYear = 0;
#     }
# }
#
# int isValidNumber(const char* str) {
#     // 空文字列チェック
#     if (str[0] == '\n' || str[0] == '\0') {
#         return 0;
#     }
#
#     // 各文字をチェック
#     for (int i = 0; str[i] != '\0' && str[i] != '\n'; i++) {
#         if (!isdigit(str[i])) {
#             return 0;
#         }
#     }
#     return 1;
# }

# %%
# %%writefile main.c
# // main.c
# #include <stdio.h>
# #include <stdlib.h>
# #include <string.h>
#
# #include "convert.h"  // ★追加：自作ヘッダーファイルをインクルード
#
# #define MAX_TESTS 100
#
# int main() {
#     FILE *fp;
#     char line[256];
#     int numTests = 0;
#     Era era;
#
#     // テストケースファイルを開く
#     fp = fopen("test_cases.txt", "r");
#     if (fp == NULL) {
#         printf("テストケースファイルを開けませんでした。\n");
#         return 1;
#     }
#
#     printf("和暦変換テストを開始します\n");
#     printf("----------------------------\n");
#
#     // ファイルから年を読み込み、変換する
#     while (fgets(line, sizeof(line), fp) && numTests < MAX_TESTS) {
#         if (!isValidNumber(line)) {
#             printf("無効な入力（行 %d）: %s", numTests + 1, line);
#             continue;
#         }
#
#         int year = atoi(line);
#         calculateEra(year, &era);
#
#         printf("西暦%d年 -> ", year);
#         if (strcmp(era.eraName, "不明") != 0) {
#             if (era.eraYear == 1) {
#                 printf("%s元年\n", era.eraName);
#             } else {
#                 printf("%s%d年\n", era.eraName, era.eraYear);
#             }
#         } else {
#             printf("対応していない年代です\n");
#         }
#         numTests++;
#     }
#
#     fclose(fp);
#     printf("----------------------------\n");
#     printf("テスト完了（有効なテストケース: %d件）\n", numTests);
#
#     return 0;
# }

# %%
# コンパイル＆実行
if compile_program():
    run_program()
